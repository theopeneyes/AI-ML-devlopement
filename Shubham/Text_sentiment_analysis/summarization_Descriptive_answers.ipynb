# %% [markdown]
# ### Installing & Importing all Libraries

# %%
# !pip install -q torch transformers accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...

# %%
# If running in Google Colab, you may need to run this cell to make sure you're using UTF-8 locale to install LangChain
import locale

locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install -q langchain
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 61.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 kB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 449.3 kB/s eta 0:00:00

# %%
import requests
import json

# %% [markdown]
# ### Fetching Response data for survey

# %%
stored_data = requests.get("https://openeyessurveys-api.devbyopeneyes.com/public/api/getSurveyStoredData/9b6f1334-03e5-4039-b8dc-dccd1a173f16")
stored_data = stored_data.json()

# %%
QA_data = stored_data["data"]["questions"]

# %%
# Function for only getting question and responses
def get_qa_data(QA_data):
  qa_data = []

  for i in QA_data:
    new_data = {}
    new_data["question_text"] = i["QuestionText"]
    new_data["responses"] = []
    for j in i["child"]:
      if "option_text" in j.keys():
        new_data["responses"].append(j["option_text"])
      elif "AnswerText" in j.keys():
        new_data["responses"].append(j["AnswerText"])
    qa_data.append(new_data)

  return qa_data

# %%
qa_data = get_qa_data(QA_data)
qa_data
# Out:
# [{'question_text': 'How would you describe the current organizational culture at current organization?',
#   'responses': ['The organizational culture is characterized by a strong sense of autonomy and independence. Employees are entrusted with decision-making authority and are encouraged to take ownership of their work, fostering a culture of accountability and self-reliance.',
#    "The organization promotes a culture of continuous improvement and excellence. There's a relentless pursuit of perfection and a commitment to delivering high-quality products/services, driving a culture of excellence and achievement.",
#    "The organizational culture is family-oriented, with a focus on fostering strong interpersonal relationships and a sense of community among employees. There's a genuine concern for each other's well-being, creating a supportive and nurturing work environment.",
# ...

# %%
question_text = []
user_responses = []

for i in qa_data:
  question_text.append(i["question_text"])
  user_responses.append(i["responses"])

# %%
print(user_responses[0])
# Out:
# ['The organizational culture is characterized by a strong sense of autonomy and independence. Employees are entrusted with decision-making authority and are encouraged to take ownership of their work, fostering a culture of accountability and self-reliance.', "The organization promotes a culture of continuous improvement and excellence. There's a relentless pursuit of perfection and a commitment to delivering high-quality products/services, driving a culture of excellence and achievement.", "The organizational culture is family-oriented, with a focus on fostering strong interpersonal relationships and a sense of community among employees. There's a genuine concern for each other's well-being, creating a supportive and nurturing work environment.", 'The organization embraces a culture of adaptability and resilience. In the face of challenges and uncertainties, employees demonstrate flexibility and resilience, quickly adapting to changing circumstances and driving organizational agilit
# ...

# %%
len(user_responses)
# Out:
# 3

# %%
responses_string  = ""
for i in user_responses[0]:
  responses_string  = responses_string + i + ","

print(responses_string)
# Out:
# The organizational culture is characterized by a strong sense of autonomy and independence. Employees are entrusted with decision-making authority and are encouraged to take ownership of their work, fostering a culture of accountability and self-reliance.,The organization promotes a culture of continuous improvement and excellence. There's a relentless pursuit of perfection and a commitment to delivering high-quality products/services, driving a culture of excellence and achievement.,The organizational culture is family-oriented, with a focus on fostering strong interpersonal relationships and a sense of community among employees. There's a genuine concern for each other's well-being, creating a supportive and nurturing work environment.,The organization embraces a culture of adaptability and resilience. In the face of challenges and uncertainties, employees demonstrate flexibility and resilience, quickly adapting to changing circumstances and driving organizational agility.,The orga
# ...

# %%
# Fetching only single question & its all responses from different users
question_text = question_text[0]
user_responses = user_responses[0]
print("Question :",question_text,"\n","Responses :",user_responses)
# Out:
# Question : How would you describe the current organizational culture at current organization?
# ...

# %% [markdown]
# ### Loading Mistral LLM with BitsAndBytes Quantization

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# ...

# %%
from langchain.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from transformers import pipeline
from langchain_core.output_parsers import StrOutputParser

text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    temperature=0.8,
    do_sample=True,
    repetition_penalty=1.1,
    return_full_text=True,
    max_new_tokens=400,
)

llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %% [markdown]
# ### Setting up prompt and output parser

# %%
# Trial -1
# prompt_template = """
# [INST]
# For the below-given question and list of different user answers delimited in triple brackets, summarize all answers and give a summary of all unique answers of users.

# Question : ```{question}```

# Answers : ```{answers}```

# [/INST]
#  """

# Trial - 2
# prompt_template = """
# [INST]
# For the below-given question and list of different user answers delimited in triple brackets, give me a short summary of all answers combined in the context of the question.
# Question : ```{question}```

# Answers : ```{answers}```

# [/INST]
#  """

# Trial - 3
# prompt_template = """
# [INST]
# For the below-given question and list of different user answers delimited in triple brackets, Summarize the main points combining all the answers in list with context of question.

# Question : ```{question}```

# Answers : ```{answers}```

# [/INST]
#  """

# Trial - 4
# prompt_template = """
# [INST]
# For the below-given question and different users answers concatenated in string delimited in triple brackets,
# Summarize user answers combining all answers as short as possible in context of question.summary should be short and combined.

# Question : ```{question}```

# Answers : ```{responses_string}```

# [/INST]
#  """

# Trial - 5
prompt_template = """
[INST]
For the below-given question and different users answers concatenated in string delimited in triple brackets,
Combining all answers give me summary in 5-6 sentences in context of question.

Question : ```{question}```

Answers : ```{responses_string}```

[/INST]
 """

# %%
# prompt = PromptTemplate(
#     input_variables=["question", "answers"],
#     template=prompt_template,
# )

prompt = PromptTemplate(
    input_variables=["question", "responses_string"],
    template=prompt_template,
)

llm_chain = prompt | llm | StrOutputParser()

# %%
# response = llm_chain.invoke({"question": question_text, "answers": user_responses})
response = llm_chain.invoke({"question": question_text, "responses_string": responses_string})
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#  The current organizational culture is quite unique and multifaceted, encompassing various elements that foster a dynamic and engaging work environment. Autonomous employees are a hallmark of this organization, with decision-making authority and accountability driving a culture of self-reliance and continuous improvement. Additionally, there's a significant emphasis on cultivating interpersonal relationships and fostering a supportive, family-oriented work environment.
#
# In the face of adversity and uncertainty, employees display remarkable adaptability and resilience, ensuring organizational agility. There's a commitment to delivering high-quality products or services and a relentless pursuit of excellence, while maintaining a flat hierarchy and decentralized decision-making structure. This empowers employees and promotes a culture of recognition and appreciation, valuing the contributions of each team member.
# ...

# %% [markdown]
# ## Iterative Prompt Engineering

# %%
# Trial -1 summaries
# Summarization for 3rd question :
"""The given question asks how organizations welcome newly joined employees. Based on the provided user answers, it is clear that there are various ways in which new employees are welcomed and integrated into an organization. Here is a summary of all unique answers:

1. Comprehensive onboarding program: New employees undergo a program designed to familiarize them with the company culture, policies, procedures, and job responsibilities.
2. Personalized welcome messages: New employees receive messages from team members, managers, and senior leadership welcoming them and offering support.
3. Buddy or mentor system: Each new employee is assigned a buddy or mentor to help them navigate their first few weeks on the job.
4. Welcome kit: New employees receive a welcome kit containing company-branded merchandise, essential tools, and a handbook.
5. Informal gathering: New employees are hosted for a welcome lunch or coffee session to meet colleagues in a relaxed setting.
6. Formal introduction: New employees are formally introduced during a company-wide meeting.
7. Welcome ambassador: Each new employee is assigned a welcome ambassador who serves as their point of contact for any questions or concerns.
8. Welcome email announcement: A welcome email is sent to the entire organization introducing the new employee and encouraging colleagues to welcome them.
9. Structured first day: New employees are provided with a detailed agenda for their first day, outlining scheduled meetings and introductions.
10. Regular check-ins: HR conducts regular check-ins with new employees to gather feedback and address any concerns or challenges they may encounter.

Overall, the common theme among these answers is the importance of providing a supportive and inclusive environment for new employees during their onboarding process. This can include a combination of formal and informal activities designed to help new hires feel welcomed, informed, and prepared for their new role."""
# Out:
# 'The given question asks how organizations welcome newly joined employees. Based on the provided user answers, it is clear that there are various ways in which new employees are welcomed and integrated into an organization. Here is a summary of all unique answers:\n\n1. Comprehensive onboarding program: New employees undergo a program designed to familiarize them with the company culture, policies, procedures, and job responsibilities.\n2. Personalized welcome messages: New employees receive messages from team members, managers, and senior leadership welcoming them and offering support.\n3. Buddy or mentor system: Each new employee is assigned a buddy or mentor to help them navigate their first few weeks on the job.\n4. Welcome kit: New employees receive a welcome kit containing company-branded merchandise, essential tools, and a handbook.\n5. Informal gathering: New employees are hosted for a welcome lunch or coffee session to meet colleagues in a relaxed setting.\n6. Formal introdu
# ...

# %%
# Trial - 2 summaries
# Summarization for 3rd question :
"""
The answers provided offer various ways in which organizations welcome newly joined employees. Some of these methods include conducting a comprehensive onboarding program,
assigning buddies or mentors, providing welcome kits, hosting welcome meals, formally introducing new hires during company-wide meetings, sending out welcome emails,
having a structured first day agenda, and conducting regular check-ins with new hires throughout the onboarding process.

Overall, these practices aim to help new employees become acquainted with the company culture, policies, procedures, and job responsibilities. New hires receive personalized
welcomes from team members, managers, and senior leadership, as well as assistance from buddies or mentors, welcome kits, and opportunities to meet colleagues.
Formal introductions during company-wide meetings and welcome emails also allow existing employees to learn more about the new hire,
encouraging a welcoming and inclusive work environment. Structured approaches such as a detailed first-day agenda and regular check-ins further help to prepare new hires for
their roles and ensure a positive onboarding experience.
"""

# %%
# Trial - 3 summaries
# Summarization for 3rd question :
"""
Upon joining an organization, new employees go through a thorough onboarding process aimed at familiarizing them with the company culture, policies, procedures, and
job responsibilities. The onboarding process begins with a welcoming message from HR and introduction to key team members and stakeholders. New hires receive personalized welcome
messages from their team members, managers, and senior leadership to foster a sense of belonging. Each new employee is assigned a buddy or mentor to help navigate their early days
on the job, providing guidance, answering questions, and sharing valuable insights.
      New employees also receive a welcome kit upon arrival, containing company-branded merchandise, essential tools for their role, and a handbook outlining company policies and
procedures. Hosting a welcome lunch or coffee session provides new hires with the opportunity to meet their colleagues in a relaxed setting and build camaraderie.
New employees are formally introduced during a company-wide meeting, allowing existing employees to get to know them, and vice versa. Each new employee is assigned a welcome
ambassador to serve as their point of contact for any queries or concerns during their first days at the company. A welcome email announcement is sent to the entire organization,
introducing the new hire and encouraging colleagues to reach out and welcome them. Providing new employees with a detailed agenda for their first day keeps them organized and
prepares them for their new role.
    Throughout the onboarding process, HR conducts regular check-ins with new employees to gather feedback on their experience and address any concerns or challenges they may face.
This proactive approach underscores the organization's commitment to supporting new hires and ensuring a successful transition into the company.
"""

# %%
# Trial - 5 summaries - prompt for shorter summary
# Summarization for 3rd question :
"""
New employees undergo a comprehensive onboarding program, including company orientation, personalized welcomes, a buddy system, a welcome kit, social events,
formal introductions, and ongoing support from HR and mentors. The organization also communicates their arrival through emails and company-wide meetings. Regular check-ins ensure
a positive onboarding experience.
"""

# %%
# Trial - 5 summaries - prompt for shorter summary upto 7-8 sentences
# Summarization for 3rd question :
"""
When new employees join an organization, they are welcomed and integrated through various means. The onboarding process begins with a comprehensive program designed to familiarize
new hires with the company culture, policies, procedures, and job responsibilities. New employees receive a warm welcome from HR and are introduced to key team members and
stakeholders. They also receive personalized messages from team members, managers, and senior leadership, expressing excitement about their arrival and offering support.
      Each new employee is assigned a buddy or mentor who guides them through their first few weeks on the job. This mentor provides valuable insights, answers questions, and
facilitates a smooth transition into the organization. Upon arrival, new hires receive a welcome kit containing company-branded merchandise, essential tools, and a handbook
outlining company policies and procedures.
      To foster camaraderie and help new hires feel included, companies host a welcome lunch or coffee session. During this informal gathering, new employees meet their colleagues
and get to know each other in a relaxed setting. New hires are also formally introduced during a company-wide meeting, allowing existing employees to learn more about their new
colleagues.
      For added support, new employees are assigned a welcome ambassador who serves as their point of contact for any questions or concerns. A welcome email announcement is sent to
the entire organization, introducing the new employee and highlighting their background, skills, and role within the company. New hires are also provided with a detailed agenda for
their first day, outlining scheduled meetings, training sessions, and introductions.
      Throughout the onboarding process, HR conducts regular check-ins with new employees to gather feedback on their experience and address any concerns. This proactive approach
demonstrates the organization's commitment to supporting new hires and ensuring a successful transition. Overall, these measures combine to create a welcoming and supportive
environment that eases the
"""

# %%
# Trial - 5 summaries - prompt for shorter summary upto 5-6 sentences
# Summarization for 3rd question :
"""
      New employees joining an organization are welcomed through a well-structured onboarding program. This program aims to familiarize new hires with the company culture, policies,
procedures, and job responsibilities. Upon joining, new employees undergo a comprehensive onboarding process that includes a welcome message from HR, team members, managers, and
senior leadership. They are also assigned a buddy or mentor and given a welcome kit containing essential tools and company merchandise.

      Furthermore, new employees are introduced during a company-wide meeting, where they can share their background and interact with existing employees. A welcome lunch or coffee
session is also arranged to help new hires build relationships with colleagues in a relaxed setting. Each new employee is provided with a welcome ambassador, acting as their point
of contact for any queries during their initial days at the company. An email announcement is also made to introduce the new hire to the broader organization.

      The onboarding process involves a structured first-day agenda and regular check-ins by HR to gather feedback and address concerns. This proactive approach demonstrates the
organization's commitment to supporting new hires and ensuring a positive transition experience. Overall, these practices create a welcoming environment for new employees, helping
them feel supported and integrated into their new roles.
"""

# %%
# Trial - 5 summaries - prompt for shorter summary upto 5-6 sentences
# Summarization for 2nd question :
"""
      The communication dynamics within the organization are marked by a culture of openness, accessibility, and collaboration. Employees can comfortably approach their colleagues
and leaders for discussions, leading to an inclusive environment that fosters empathy and mutual respect. The organization prioritizes transparency and regular communication, with
leaders keeping employees informed about organizational updates and initiatives. Effective use of technology is employed to facilitate communication and collaboration, especially
across geographical locations. A culture of constructive feedback and continuous improvement is encouraged, enabling a learning and development focused work environment.
Storytelling is utilized as a powerful tool to inspire, engage, and align employees around the organization's mission, vision, and values. Transparency and accountability are
valued, with clear communication about organizational goals, performance, and challenges fostering a trusting atmosphere. Face-to-face communication and interpersonal relationships
remain essential, supplementing digital communication channels and enabling the building of strong employee relationships. Overall, this organization prioritizes multiple
communication styles and channels to ensure effective and adaptive communication that caters to its diverse workforce.

"""

# %%
# Trial - 5 summaries - prompt for shorter summary upto 5-6 sentences
# Summarization for 1st question :

"""
        The current organizational culture is quite unique and multifaceted, encompassing various elements that foster a dynamic and engaging work environment. Autonomous employees
are a hallmark of this organization, with decision-making authority and accountability driving a culture of self-reliance and continuous improvement. Additionally, there's a
significant emphasis on cultivating interpersonal relationships and fostering a supportive, family-oriented work environment.

        In the face of adversity and uncertainty, employees display remarkable adaptability and resilience, ensuring organizational agility. There's a commitment to delivering
high-quality products or services and a relentless pursuit of excellence, while maintaining a flat hierarchy and decentralized decision-making structure. This empowers employees
and promotes a culture of recognition and appreciation, valuing the contributions of each team member.

        Moreover, the organization places great importance on work-life balance, offering flexible work arrangements, and wellness initiatives to support employee well-being.
The diverse workforce enjoys an inclusive and respectful environment, and the organization actively works towards promoting sustainability and corporate social responsibility.
In essence, the current organizational culture embodies a balance between autonomy, accountability, interpersonal connections, and customer focus.

"""
