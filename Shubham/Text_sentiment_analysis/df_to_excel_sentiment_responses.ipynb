# %%
import pandas as pd

# %%
data = [{'ques_text': 'How satisfied are you overall with your experience at school?',
  'responses': [{'user_answer': 'Extremely Dissatisfied',
    'sentiment': 'No sentiment generated',
    'score': '-1.0'},
   {'user_answer': ' Dissatisfied',
    'sentiment': 'No sentiment generated',
    'score': '-0.9'},
   {'user_answer': ' Neutral', 'sentiment': 'Neutral', 'score': '0.5'},
   {'user_answer': 'Satisfied',
    'sentiment': 'No sentiment generated',
    'score': '0.9'},
   {'user_answer': 'Extremely Satisfied',
    'sentiment': 'No sentiment generated',
    'score': '0.9'}]},
 {'ques_text': 'What are the three main things you think your school could improve upon?',
  'responses': [{'user_answer': 'I appreciate the diverse range of academic resources available, but there could be more access to online resources and updated technology in classrooms to enhance the learning experience.',
    'sentiment': 'Possitive',
    'score': '0.8'},
   {'user_answer': 'In school lots of things need to improve there is nothing in school all is bad experience for our batch of students.',
    'sentiment': 'Negative',
    'score': '-0.8'},
   {'user_answer': 'The school needs to be proactive in sharing important information through newsletters, emails, and an online portal.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'There might be a need to expand extracurricular options to cater to a wider range of interests and talents.',
    'sentiment': 'Possitive',
    'score': '0.8'},
   {'user_answer': 'Certain areas, such as restrooms or some classrooms, could benefit from more regular maintenance and updates.',
    'sentiment': 'Neutral',
    'score': '0.5'},
   {'user_answer': 'There may be an opportunity to enhance the support system for students navigating the college application process, including more personalized counseling.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'All is good at school every thing is perfect for me.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'School need to improve teachers quality, canteen food also hostel services.',
    'sentiment': 'Negative',
    'score': '-0.7'},
   {'user_answer': 'There is nothing to improve all is good and average in school.',
    'sentiment': 'Neutral',
    'score': '0.8'}]},
 {'ques_text': 'What kind of support systems are available to students at school?',
  'responses': [{'user_answer': 'Schools provide tutoring services for students who need extra help with specific subjects. This Tutoring will be one-on-one or in small groups helps for student.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'Some support staff, such as counselors or teachers, may not have adequate training or resources to address the diverse needs of students, particularly those with complex challenges.',
    'sentiment': 'Negative',
    'score': '-0.9'},
   {'user_answer': 'Academic counselors help students with academic planning, course selection, and college admissions.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'There will be no any support from school in any way. All teachers are less experience, no any goals for school as students.',
    'sentiment': 'Negative',
    'score': '-0.95'},
   {'user_answer': "schools offer mental health resources, such as partnerships with mental health professionals or access to online mental health tools, to support students' emotional well-being.",
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'I am not impressed with support of school for students for scholarship or sponsorship for higher education.',
    'sentiment': 'Negative',
    'score': '-0.9'},
   {'user_answer': 'There is very good support from faculty of school for future higher education.',
    'sentiment': 'Possitive',
    'score': '0.95'},
   {'user_answer': 'There is no support from school or teachers to students at all.',
    'sentiment': 'Negative',
    'score': '-0.9'},
   {'user_answer': 'Support for student is average and neutral for students.',
    'sentiment': 'Neutral',
    'score': '0.5'}]},
 {'ques_text': 'How would you rate the overall communication between students and teachers at  school?',
  'responses': [{'user_answer': 'Students feel comfortable approaching teachers with questions or concerns, and teachers are open to feedback and suggestions.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'Teachers use jargon or overly complex language that students struggle to grasp. Explanations lack clarity or fail to address student misconceptions',
    'sentiment': 'Negative',
    'score': '-0.8'},
   {'user_answer': 'Teachers respond promptly to emails, messages, or other forms of communication from students. They provide timely feedback on assignments and address student inquiries efficiently.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': "Teachers' communication patterns are inconsistent or unreliable. They may change communication methods or response times without notice, causing confusion and frustration.",
    'sentiment': 'Negative',
    'score': '-0.8'},
   {'user_answer': 'Teachers integrate technology effectively to enhance communication and engagement. They use online platforms, messaging tools, and interactive resources to facilitate communication with students.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': "Teachers' communication patterns are inconsistent or unreliable. They may change communication methods or response times without notice, causing confusion and frustration.",
    'sentiment': 'Negative',
    'score': '-0.9'},
   {'user_answer': 'Teachers encourage open communication and collaboration among students. They create opportunities for students to share ideas, ask questions, and learn from each other.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'Teachers are hesitant to adopt technology or struggle to use it effectively. They may rely solely on traditional methods, limiting communication opportunities.',
    'sentiment': 'Negative',
    'score': '-0.8'},
   {'user_answer': 'There is normal and average communication between students and teachers.',
    'sentiment': 'Neutral',
    'score': '0.5'}]},
 {'ques_text': 'Which activities in the classroom do you enjoy the most?',
  'responses': [{'user_answer': 'Group discussions and problem-solving exercises',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'Playing sports ',
    'sentiment': 'Possitive',
    'score': '0.8'},
   {'user_answer': 'Making fun of teachers',
    'sentiment': 'Negative',
    'score': '-0.8'},
   {'user_answer': 'Making chaos in classroom',
    'sentiment': 'Negative',
    'score': '-0.8'}]},
 {'ques_text': 'Will you recommend our company to other students? also state reason?',
  'responses': [{'user_answer': 'Absolutely! I would recommend the company because of its positive work environment. The team collaboration and supportive atmosphere make it an enjoyable place to work.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'I might hesitate to recommend the school due to limited extracurricular options. Expanding the range of activities could better cater to diverse student interests.',
    'sentiment': 'Negative',
    'score': '0.9'},
   {'user_answer': 'I highly recommend the school for its inclusive and diverse community. The school promotes a welcoming environment that celebrates differences and fosters a sense of belonging.',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'I might not recommend the company to others because of concerns about work-life balance. There have been instances of tight deadlines impacting personal time.',
    'sentiment': 'Negative',
    'score': '0.8'},
   {'user_answer': "Yes, I would recommend the school. The communication with parents is transparent and timely, keeping families well-informed about school events, updates, and their child's progress.",
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'I have reservations about recommending the school due to communication gaps with students. More efforts could be made to ensure students are well-informed about important school matters.',
    'sentiment': 'Negative',
    'score': '0.9'},
   {'user_answer': 'Absolutely! I would recommend the school because of its excellent academic programs',
    'sentiment': 'Possitive',
    'score': '0.9'},
   {'user_answer': 'I have reservations about recommending the school due to communication gaps with students. More efforts could be made to ensure students are well-informed about important school matters.',
    'sentiment': 'Negative',
    'score': '0.9'},
   {'user_answer': 'Is neutral reaction from my side to school so i will not prefer to recommend to anyone.',
    'sentiment': 'Negative',
    'score': '0.8'}]}]

# %%
new_data = {}
new_data["ques_text"] = []
new_data["responses"] = []
for i in data:
  new_data["ques_text"].append(i["ques_text"])
  res = []
  for j in i["responses"] :
    res.append(j)
  new_data["responses"].append(res)

# %%
new_data
# Out:
# {'ques_text': ['How satisfied are you overall with your experience at school?',
#   'What are the three main things you think your school could improve upon?',
#   'What kind of support systems are available to students at school?',
#   'How would you rate the overall communication between students and teachers at  school?',
#   'Which activities in the classroom do you enjoy the most?',
#   'Will you recommend our company to other students? also state reason?'],
#  'responses': [[{'user_answer': 'Extremely Dissatisfied',
#     'sentiment': 'No sentiment generated',
#     'score': '-1.0'},
#    {'user_answer': ' Dissatisfied',
#     'sentiment': 'No sentiment generated',
#     'score': '-0.9'},
#    {'user_answer': ' Neutral', 'sentiment': 'Neutral', 'score': '0.5'},
#    {'user_answer': 'Satisfied',
#     'sentiment': 'No sentiment generated',
#     'score': '0.9'},
#    {'user_answer': 'Extremely Satisfied',
#     'sentiment': 'No sentiment generated',
#     'score': '0.9'}],
# ...

# %%
# Flatten the nested structure
flat_data = {'ques_text': [], 'response': [], 'sentiment': [], 'score': []}
for i, question in enumerate(new_data['ques_text']):
    for response in new_data['responses'][i]:
        flat_data['ques_text'].append(question)
        flat_data['response'].append(response['user_answer'])
        flat_data['sentiment'].append(response['sentiment'])
        flat_data['score'].append(response['score'])

# %%
df1 = pd.DataFrame(flat_data)
df1.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#                 sentiment score
# 0  No sentiment generated  -1.0
# 1  No sentiment generated  -0.9
# 2                 Neutral   0.5
# 3  No sentiment generated   0.9
# 4  No sentiment generated   0.9

# %%
df1.shape
# Out:
# (45, 4)

# %%
df1.to_excel("GPT_sentiment_responses.xlsx")

# %% [markdown]
# # Without sentiment_score

# %% [markdown]
# #### For Llama-2 Sentiments

# %%
import pandas as pd

# %%
data = [{'ques_text': 'How satisfied are you overall with your experience at school?',
  'responses': [{'Extremely Dissatisfied': {'sentiments': 'Negative'}},
   {'Dissatisfied': {'sentiments': 'Negative'}},
   {'Neutral': 'Sentiment not generated.'},
   {'Satisfied': {'sentiments': 'Positive'}},
   {'Extremely Satisfied': {'sentiments': 'Positive'}}]},
 {'ques_text': 'What kind of support systems are available to students at school?',
  'responses': [{"My school offers a ton of support! There's academic tutoring, college counseling even mental health counselors and peer mentoring programs. I feel like I can always find someone to help me with whatever I'm struggling with.": {'sentiments': 'positive'}},
   {'Schools typically provide a range of support services, such as counseling and tutoring, to address the diverse needs of students. The effectiveness may vary depending on individual circumstances.': {'sentiments': 'Neutral'}},
   {"Unfortunately, my school's support systems are pretty limited. There's barely any tutoring, the counselors are overloaded, and the resources they offer are outdated or unhelpful. I feel like I'm on my own most of the time.": 'Sentiment not generated.'},
   {"The teachers at my school are amazing! They're always willing to help with extra explanations, offer different learning strategies, and encourage us to ask questions. They genuinely care about our success and make themselves available outside of class.": {'sentiments': 'positive'}},
   {"There's a stigma around seeking help at my school. People can be judgmental, and even the teachers don't always seem comfortable discussing mental health or learning challenges openly. It makes it difficult to reach out for the support you need.": {'sentiments': 'NEGATIVE'}}]},
 {'ques_text': 'How would you rate the overall communication between students and teachers at  school?',
  'responses': [{"Communication feels two-way and respectful. Teachers encourage questions, actively listen to feedback, and explain things clearly. There's a sense of open dialogue and collaboration in the classroom.": {'sentiments': 'positive'}},
   {'The communication between students and teachers at our school is generally satisfactory, with some variability depending on individual teacher-student dynamics. It is neither notably exceptional nor deficient.': {'sentiments': 'neutral'}},
   {"Communication often feels one-directional, with teachers delivering information and students passively receiving it. There's limited opportunities for student questions, discussions, or active participation.": {'sentiments': 'neutral'}},
   {'The school prioritizes clear communication through initiatives like regular feedback surveys, student forums, and open office hours. It feels like our voices are heard and valued, creating a more inclusive learning environment.': {'sentiments': 'positive'}},
   {"In some cases, there's a lack of trust and transparency, making it difficult to have open and honest conversations with teachers. Important information isn't always shared clearly, and student concerns can be dismissed.": {'sentiments': 'neutral'}}]},
 {'ques_text': 'Which activities in the classroom do you enjoy the most?',
  'responses': [{'Group discussions and problem-solving exercises': {'sentiments': 'positive'}},
   {'Playing sports ': {'sentiments': 'positive'}},
   {'Making fun of teachers': {'sentiments': 'Negative'}},
   {'Making chaos in classroom': {'sentiments': 'negative'}}]},
 {'ques_text': 'Will you recommend our school to other students/your friends? also state reason?',
  'responses': [{"Absolutely! This school has provided me with amazing opportunities, supportive teachers, and a positive learning environment. I've grown academically and personally, and I feel confident recommending it to anyone looking for a well-rounded educational experience.": {'sentiments': 'Positive'}},
   {'I would consider recommending our school to others. It provides a decent educational experience, but individual preferences and goals may vary, so I would suggest exploring different options based on personal needs.': {'sentiments': 'neutral'}},
   {"I've had some negative experiences. The study can be overwhelming, and the pressure to excel can be stressful. Additionally, teaching method, which might not be ideal for everyone. It's important to consider all aspects before making a decision.": 'Sentiment not generated.'},
   {'Without a doubt! The academics are challenging but rewarding, with passionate teachers who genuinely care about student success. There\'s a strong sense of community, and there\'s something for everyone with clubs, extracurriculars, and diverse support systems."': {'sentiments': 'positive'}},
   {'I would hesitate to recommend our school due to issues like inadequate resources and outdated facilities. While the education is satisfactory, there are better options available.': {'sentiments': 'negative'}}]}]

# %%
new_data = {}
new_data["ques_text"] = []
new_data["responses"] = []
for i in data:
  new_data["ques_text"].append(i["ques_text"])
  res = []
  for j in i["responses"] :
    res.append(j)
  new_data["responses"].append(res)

# %%
new_data
# Out:
# {'ques_text': ['How satisfied are you overall with your experience at school?',
#   'What kind of support systems are available to students at school?',
#   'How would you rate the overall communication between students and teachers at  school?',
#   'Which activities in the classroom do you enjoy the most?',
#   'Will you recommend our school to other students/your friends? also state reason?'],
#  'responses': [[{'Extremely Dissatisfied': {'sentiments': 'Negative'}},
#    {'Dissatisfied': {'sentiments': 'Negative'}},
#    {'Neutral': 'Sentiment not generated.'},
#    {'Satisfied': {'sentiments': 'Positive'}},
#    {'Extremely Satisfied': {'sentiments': 'Positive'}}],
#   [{"My school offers a ton of support! There's academic tutoring, college counseling even mental health counselors and peer mentoring programs. I feel like I can always find someone to help me with whatever I'm struggling with.": {'sentiments': 'positive'}},
# ...

# %%
# Flatten the nested structure
flat_data = {'ques_text': [], 'response': [], 'sentiment': []}
for i, question in enumerate(new_data['ques_text']):
    for response in new_data['responses'][i]:
      flat_data['ques_text'].append(question)
      flat_data['response'].append(list(response.keys())[0])
      try :
        flat_data['sentiment'].append(list(response.values())[0]["sentiments"])
      except :
        flat_data['sentiment'].append("Sentiment not generated")

# %%
flat_data
# Out:
# {'ques_text': ['How satisfied are you overall with your experience at school?',
#   'How satisfied are you overall with your experience at school?',
#   'How satisfied are you overall with your experience at school?',
#   'How satisfied are you overall with your experience at school?',
#   'How satisfied are you overall with your experience at school?',
#   'What kind of support systems are available to students at school?',
#   'What kind of support systems are available to students at school?',
#   'What kind of support systems are available to students at school?',
#   'What kind of support systems are available to students at school?',
#   'What kind of support systems are available to students at school?',
#   'How would you rate the overall communication between students and teachers at  school?',
#   'How would you rate the overall communication between students and teachers at  school?',
# ...

# %%
df = pd.DataFrame(flat_data)

# %%
df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#                  sentiment
# 0                 Negative
# 1                 Negative
# 2  Sentiment not generated
# 3                 Positive
# 4                 Positive

# %%
# df.to_excel("Llama-2_sentiment_analysis.xlsx")

# %% [markdown]
# ### For GPT-API

# %%
data = [{'ques_text': 'How satisfied are you overall with your experience at school?',
  'responses': [{'user_answer': 'Extremely Dissatisfied',
    'sentiment': 'negative'},
   {'user_answer': 'Dissatisfied', 'sentiment': 'negative'},
   {'user_answer': 'Neutral', 'sentiment': 'neutral'},
   {'user_answer': 'Satisfied', 'sentiment': 'positive'},
   {'user_answer': 'Extremely Satisfied', 'sentiment': 'positive'}]},
 {'ques_text': 'What kind of support systems are available to students at school?',
  'responses': [{'user_answer': "My school offers a ton of support! There's academic tutoring, college counseling even mental health counselors and peer mentoring programs. I feel like I can always find someone to help me with whatever I'm struggling with.",
    'sentiment': 'positive'},
   {'user_answer': 'Schools typically provide a range of support services, such as counseling and tutoring, to address the diverse needs of students. The effectiveness may vary depending on individual circumstances.',
    'sentiment': 'positive'},
   {'user_answer': "Unfortunately, my school's support systems are pretty limited. There's barely any tutoring, the counselors are overloaded, and the resources they offer are outdated or unhelpful. I feel like I'm on my own most of the time.",
    'sentiment': 'negative'},
   {'user_answer': "The teachers at my school are amazing! They're always willing to help with extra explanations, offer different learning strategies, and encourage us to ask questions. They genuinely care about our success and make themselves available outside of class.",
    'sentiment': 'positive'},
   {'user_answer': "There's a stigma around seeking help at my school. People can be judgmental, and even the teachers don't always seem comfortable discussing mental health or learning challenges openly. It makes it difficult to reach out for the support you need.",
    'sentiment': 'negative'}]},
 {'ques_text': 'How would you rate the overall communication between students and teachers at  school?',
  'responses': [{'user_answer': "Communication feels two-way and respectful. Teachers encourage questions, actively listen to feedback, and explain things clearly. There's a sense of open dialogue and collaboration in the classroom.",
    'sentiment': 'positive'},
   {'user_answer': 'The communication between students and teachers at our school is generally satisfactory, with some variability depending on individual teacher-student dynamics. It is neither notably exceptional nor deficient.',
    'sentiment': 'neutral'},
   {'user_answer': "Communication often feels one-directional, with teachers delivering information and students passively receiving it. There's limited opportunities for student questions, discussions, or active participation.",
    'sentiment': 'negative'},
   {'user_answer': 'The school prioritizes clear communication through initiatives like regular feedback surveys, student forums, and open office hours. It feels like our voices are heard and valued, creating a more inclusive learning environment.',
    'sentiment': 'positive'},
   {'user_answer': "In some cases, there's a lack of trust and transparency, making it difficult to have open and honest conversations with teachers. Important information isn't always shared clearly, and student concerns can be dismissed.",
    'sentiment': 'negative'}]},
 {'ques_text': 'Which activities in the classroom do you enjoy the most?',
  'responses': [{'user_answer': 'Group discussions and problem-solving exercises',
    'sentiment': 'positive'},
   {'user_answer': 'Playing sports ', 'sentiment': 'neutral'},
   {'user_answer': 'Making fun of teachers', 'sentiment': 'negative'},
   {'user_answer': 'Making chaos in classroom', 'sentiment': 'negative'}]},
 {'ques_text': 'Will you recommend our school to other students/your friends? also state reason?',
  'responses': [{'user_answer': "Absolutely! This school has provided me with amazing opportunities, supportive teachers, and a positive learning environment. I've grown academically and personally, and I feel confident recommending it to anyone looking for a well-rounded educational experience.",
    'sentiment': 'positive'},
   {'user_answer': 'I would consider recommending our school to others. It provides a decent educational experience, but individual preferences and goals may vary, so I would suggest exploring different options based on personal needs.',
    'sentiment': 'positive'},
   {'user_answer': "I've had some negative experiences. The study can be overwhelming, and the pressure to excel can be stressful. Additionally, teaching method, which might not be ideal for everyone. It's important to consider all aspects before making a decision.",
    'sentiment': 'negative'},
   {'user_answer': 'Without a doubt! The academics are challenging but rewarding, with passionate teachers who genuinely care about student success. There\'s a strong sense of community, and there\'s something for everyone with clubs, extracurriculars, and diverse support systems."',
    'sentiment': 'positive'},
   {'user_answer': 'I would hesitate to recommend our school due to issues like inadequate resources and outdated facilities. While the education is satisfactory, there are better options available.',
    'sentiment': 'negative'}]}]

# %%
new_data = {}
new_data["ques_text"] = []
new_data["responses"] = []
for i in data:
  new_data["ques_text"].append(i["ques_text"])
  res = []
  for j in i["responses"] :
    res.append(j)
  new_data["responses"].append(res)

# %%
# Flatten the nested structure
flat_data = {'ques_text': [], 'response': [], 'sentiment': []}
for i, question in enumerate(new_data['ques_text']):
    for response in new_data['responses'][i]:
        flat_data['ques_text'].append(question)
        flat_data['response'].append(response['user_answer'])
        flat_data['sentiment'].append(response['sentiment'])

# %%
GPT_df = pd.DataFrame(flat_data)
GPT_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#   sentiment
# 0  negative
# 1  negative
# 2   neutral
# 3  positive
# 4  positive

# %%
# GPT_df.to_excel("GPT_sentiment_analysis.xlsx")

# %% [markdown]
# ### For Gemini Pro API

# %%
data = [{'ques_text': 'How satisfied are you overall with your experience at school?',
  'responses': [{'Extremely Dissatisfied': {'Sentiment Class': 'negative'}},
   {'Dissatisfied': {'Sentiment Class': 'negative'}},
   {'Neutral': {'Sentiment Class': 'neutral'}},
   {'Satisfied': {'Sentiment Class': 'positive'}},
   {'Extremely Satisfied': {'Sentiment Class': 'positive'}}]},
 {'ques_text': 'What kind of support systems are available to students at school?',
  'responses': [{"My school offers a ton of support! There's academic tutoring, college counseling even mental health counselors and peer mentoring programs. I feel like I can always find someone to help me with whatever I'm struggling with.": {'Sentiment Class': 'positive'}},
   {'Schools typically provide a range of support services, such as counseling and tutoring, to address the diverse needs of students. The effectiveness may vary depending on individual circumstances.': {'Sentiment Class': 'neutral'}},
   {"Unfortunately, my school's support systems are pretty limited. There's barely any tutoring, the counselors are overloaded, and the resources they offer are outdated or unhelpful. I feel like I'm on my own most of the time.": {'Sentiment Class': 'negative'}},
   {"The teachers at my school are amazing! They're always willing to help with extra explanations, offer different learning strategies, and encourage us to ask questions. They genuinely care about our success and make themselves available outside of class.": {'Sentiment Class': 'positive'}},
   {"There's a stigma around seeking help at my school. People can be judgmental, and even the teachers don't always seem comfortable discussing mental health or learning challenges openly. It makes it difficult to reach out for the support you need.": {'Sentiment Class': 'negative'}}]},
 {'ques_text': 'How would you rate the overall communication between students and teachers at  school?',
  'responses': [{"Communication feels two-way and respectful. Teachers encourage questions, actively listen to feedback, and explain things clearly. There's a sense of open dialogue and collaboration in the classroom.": {'Sentiment Class': 'positive'}},
   {'The communication between students and teachers at our school is generally satisfactory, with some variability depending on individual teacher-student dynamics. It is neither notably exceptional nor deficient.': {'Sentiment Class': 'neutral'}},
   {"Communication often feels one-directional, with teachers delivering information and students passively receiving it. There's limited opportunities for student questions, discussions, or active participation.": {'Sentiment Class': 'negative'}},
   {'The school prioritizes clear communication through initiatives like regular feedback surveys, student forums, and open office hours. It feels like our voices are heard and valued, creating a more inclusive learning environment.': {'Sentiment Class': 'positive'}},
   {"In some cases, there's a lack of trust and transparency, making it difficult to have open and honest conversations with teachers. Important information isn't always shared clearly, and student concerns can be dismissed.": {'Sentiment Class': 'negative'}}]},
 {'ques_text': 'Which activities in the classroom do you enjoy the most?',
  'responses': [{'Group discussions and problem-solving exercises': {'Sentiment Class': 'positive'}},
   {'Playing sports ': {'Sentiment Class': 'negative'}},
   {'Making fun of teachers': {'Sentiment Class': 'negative'}},
   {'Making chaos in classroom': {'Sentiment Class': 'negative'}}]},
 {'ques_text': 'Will you recommend our school to other students/your friends? also state reason?',
  'responses': [{"Absolutely! This school has provided me with amazing opportunities, supportive teachers, and a positive learning environment. I've grown academically and personally, and I feel confident recommending it to anyone looking for a well-rounded educational experience.": {'Sentiment Class': 'positive'}},
   {'I would consider recommending our school to others. It provides a decent educational experience, but individual preferences and goals may vary, so I would suggest exploring different options based on personal needs.': {'Sentiment Class': 'neutral'}},
   {"I've had some negative experiences. The study can be overwhelming, and the pressure to excel can be stressful. Additionally, teaching method, which might not be ideal for everyone. It's important to consider all aspects before making a decision.": {'Sentiment Class': 'negative'}},
   {'Without a doubt! The academics are challenging but rewarding, with passionate teachers who genuinely care about student success. There\'s a strong sense of community, and there\'s something for everyone with clubs, extracurriculars, and diverse support systems."': {'Sentiment Class': 'positive'}},
   {'I would hesitate to recommend our school due to issues like inadequate resources and outdated facilities. While the education is satisfactory, there are better options available.': {'Sentiment Class': 'negative'}}]}]

# %%
new_data = {}
new_data["ques_text"] = []
new_data["responses"] = []
for i in data:
  new_data["ques_text"].append(i["ques_text"])
  res = []
  for j in i["responses"] :
    res.append(j)
  new_data["responses"].append(res)

# %%
# Flatten the nested structure
flat_data = {'ques_text': [], 'response': [], 'sentiment': []}
for i, question in enumerate(new_data['ques_text']):
    for response in new_data['responses'][i]:
      flat_data['ques_text'].append(question)
      flat_data['response'].append(list(response.keys())[0])
      try :
        flat_data['sentiment'].append(list(response.values())[0]["Sentiment Class"])
      except :
        flat_data['sentiment'].append("Sentiment not generated")

# %%
gemini_df = pd.DataFrame(flat_data)
gemini_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#   sentiment
# 0  negative
# 1  negative
# 2   neutral
# 3  positive
# 4  positive

# %%
gemini_df.shape
# Out:
# (24, 3)

# %%
gemini_df.to_excel("Gemini_sentiment_analysis.xlsx")

# %%
GPT_df = pd.read_excel(r"/content/GPT_sentiment_analysis.xlsx")
llama_df = pd.read_excel(r"/content/Llama-2_sentiment_analysis.xlsx")

# %%
GPT_df.drop("Unnamed: 0",axis=1,inplace=True)
llama_df.drop("Unnamed: 0",axis=1,inplace=True)

# %% [markdown]
# ## Comaprision - Joining Two Dataframes

# %%
GPT_df = pd.read_excel(r"/content/GPT_sentiment_analysis.xlsx")
GPT_df.drop("Unnamed: 0",axis=1,inplace=True)
GPT_df.rename({'sentiment':"GPT_sentiment"},axis=1,inplace=True)
GPT_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#   GPT_sentiment
# 0      negative
# 1      negative
# 2       neutral
# 3      positive
# 4      positive

# %%
Llama_df = pd.read_excel(r"/content/Llama-2_sentiment_analysis.xlsx")
Llama_df.drop("Unnamed: 0",axis=1,inplace=True)
Llama_df.rename({'sentiment':"Llama_sentiment"},axis=1,inplace=True)
Llama_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#            Llama_sentiment
# 0                 Negative
# 1                 Negative
# 2  Sentiment not generated
# 3                 Positive
# 4                 Positive

# %%
GPT_df.shape,Llama_df.shape
# Out:
# ((24, 3), (24, 3))

# %%
new_df = pd.merge(GPT_df,llama_df,on=["ques_text","response"])

# %%
new_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#   sentiment_x              sentiment_y
# 0    negative                 Negative
# 1    negative                 Negative
# 2     neutral  Sentiment not generated
# 3    positive                 Positive
# 4    positive                 Positive

# %%
new_df.shape
# Out:
# (24, 4)

# %%
new_df.rename({"sentiment_x":"GPT_sentiment","sentiment_y":"Llama_sentiment"},axis=1,inplace=True)

# %%
new_df = pd.merge(new_df,gemini_df,on=["ques_text","response"])

# %%
new_df.head()
# Out:
#                                            ques_text                response  \
# 0  How satisfied are you overall with your experi...  Extremely Dissatisfied
# 1  How satisfied are you overall with your experi...            Dissatisfied
# 2  How satisfied are you overall with your experi...                 Neutral
# 3  How satisfied are you overall with your experi...               Satisfied
# 4  How satisfied are you overall with your experi...     Extremely Satisfied
#
#   GPT_sentiment          Llama_sentiment Gemini_sentiment
# 0      negative                 Negative         negative
# 1      negative                 Negative         negative
# 2       neutral  Sentiment not generated          neutral
# 3      positive                 Positive         positive
# 4      positive                 Positive         positive

# %%
new_df.rename({"sentiment":"Gemini_sentiment"},axis=1,inplace=True)

# %%
new_df.to_excel("sentmient_comparision.xlsx")
